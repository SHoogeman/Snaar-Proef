# %%
import numpy as np

# %%
L = 0.1e-6 # H
C = 1e-6 # F

f = 1/2/np.pi/(L*C)**0.5

print("LC Frequency is: %.2f kHz" % (f/1e3))
# Out:
# LC Frequency is: 503.29 kHz

# %%
L = 4.3e-6
R = 50

t = L/R/1e-9

print("RL time is %.2e ns" % t)
# Out:
# RL time is 8.60e+01 ns
